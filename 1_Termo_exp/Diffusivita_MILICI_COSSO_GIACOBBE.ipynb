# %% [markdown]
# # Misura diffusività termica

# %% [markdown]
# ### Andrea Milici, Federico Giacobbe, Andrea Cosso

# %% [markdown]
# ## Dati e breve analisi

# %% [markdown]
# I seguenti sono i dati relativi a tre impulsi,rispettivamente 1.5s (in verde), 1s ( in blu), 0.5s (in giallo).
# Fittiamo con la funzione del tempo
# \begin{equation}
# T(t)-T_0=\frac{C}{\sqrt{Dt}}\exp^{-\frac{x^2}{4Dt}}=\frac{p_0}{\sqrt{p_1t}}\exp^{-\frac{p_2^2}{4p_1t}}
# \end{equation}

# %% [markdown]
# ![Screenshot%202023-04-11%20at%2017-32-22%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202023-04-11%20at%2017-32-22%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# I risultati dei fit sono:

# %% [markdown]
# ![Screenshot%202023-04-11%20at%2017-32-38%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202023-04-11%20at%2017-32-38%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# I risultati dei fit sono nell'ordine seguente: Impulso di 1.5 secondi, 1.0 secondi, 0.5 secondi. Parametri: p0 = C, p1 = D diffusivita termica, p2 = offset. Per una stima della diffusività termica D abbiamo fatto una media sui valori ottenuti dai tre fit, il risultato ottenuto è:
# \begin{equation}
# D=(8.56\pm 0.08)10^{-6}m^2/s
# \end{equation}

# %% [markdown]
# Per quanto riguarda l'analisi tramite fit della relazione linearizzata. Fittiamo i dati nel tratto in cui ci aspettiamo valga la relazione lineare in funzione di 1/t:
#
#  \begin{equation}
#  log((T(x,t)-T_0)\sqrt{t})=log(\frac{C}{\sqrt{D}})-\frac{x^2}{4Dt} \implies y=log(\frac{p_0}{\sqrt{p_1}})-\frac{p_2^2}{4p_1 t}
#  \end{equation}

# %% [markdown]
# ![Screenshot%202023-04-11%20at%2018-18-25%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202023-04-11%20at%2018-18-25%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# ![Screenshot%202023-04-11%20at%2018-18-37%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202023-04-11%20at%2018-18-37%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# Il coefficiente di diffusione ottenuto dalla media dei fit lineari è lineare: 2.72819e-06 +/- 4.55172e-08 m^2/s
#
# \begin{equation}
# D=(2.73\pm 0.06)10^{-6}m^2/s
# \end{equation}
# Il risultato della linearizzazione non può essere preso in considerazione in quanto non compatibile sia visivamente sul grafico che numericamente (incompatibilità) con i valori ottenuti dalla relazione T(t).

# %% [markdown]
# # Controllo temperatura del serbatio durante presa dati

# %% [markdown]
# ![Screenshot%202023-04-11%20at%2018-35-46%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202023-04-11%20at%2018-35-46%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# ![Screenshot%202023-04-11%20at%2018-34-45%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png](attachment:Screenshot%202023-04-11%20at%2018-34-45%20Risultsti_esp_1%20-%20Jupyter%20Notebook.png)

# %% [markdown]
# Possiamo affermare che la temperatura del serbatoio sia rimasta pressochè costante. Tuttavia è presente un grande offset sulla temperatura assoluta, incompatibile con la temperatura ambientale al momento della presa dati. Attribuiamo ciò alla scarsa precisione con cui abbiamo misurato la corrente che scorreva nella pt100.
